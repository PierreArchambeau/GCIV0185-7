# %% [markdown]
# Dans un Notebook Jupyter, 2 types de cellules existent :
#  - Markdown
#  - Code
#
# Dans une cellule de texte, vous pouvez utiliser du formattage, ajouter des équations, importer des fichiers...
#
# Voir pour plus d'infos : https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html

# %% [markdown]
# # Import de modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from module_test import premier_test # Import d'un module personnel du même répertoire
from submodule.module_test2 import second_test # Import d'un module personnel d'un sous-répertoire

# %% [markdown]
# # Une équation
#
# En ligne  : $e^{i\pi} + 1 = 0$
#
# Isolée : $$e^{i\pi} + 1 = 0$$

# %% [markdown]
# ## Un peu de code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Import d'une image
#
# <img src="python_logo.svg" />

# %%
premier_test(25)
premier_test(a = 28)
second_test(33)
second_test(b = 50)
# Out:
# Le paramètre a est égal à 25
# Le paramètre a est égal à 28
# Le paramètre b est égal à 33
# Le paramètre b est égal à 50

# %%
x,y = np.meshgrid(np.linspace(-5,5,100),np.linspace(-5,5,100))
z = np.sin(x)*np.cos(y)

fig, ax = plt.subplots()
c = ax.contourf(x,y,z)
ax.set_xlabel("x [$m^2$]")
ax.set_ylabel("y [$m^2$]")
fig.colorbar(c)
plt.show()
